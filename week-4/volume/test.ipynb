# %%
hi = 9

# %%
print(hi)
# Out:
# 9

# %%
import wave

with wave.open("input.wav", "rb") as wav:
    print("Channels:", wav.getnchannels())
    print("Sample width:", wav.getsampwidth())
    print("Sample rate:", wav.getframerate())
    print("Frames:", wav.getnframes())
# Out:
# Channels: 2
# Sample width: 2
# Sample rate: 44100
# Frames: 88200

# %%
with open("input.wav", "rb") as f:
    data = f.read()

print(data[:100])
# Out:
# b'RIFFDb\x05\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x02\x00D\xac\x00\x00\x10\xb1\x02\x00\x04\x00\x10\x00data b\x05\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
wave_file = wave.open("input.wav", "wb")
# Out:
# Exception ignored while calling deallocator <function Wave_write.__del__ at 0x7304b418c300>:
# Traceback (most recent call last):
#   File "/home/kisuke-34/.local/share/uv/python/cpython-3.14-linux-x86_64-gnu/lib/python3.14/wave.py", line 471, in __del__
#     self.close()
#   File "/home/kisuke-34/.local/share/uv/python/cpython-3.14-linux-x86_64-gnu/lib/python3.14/wave.py", line 595, in close
#     self._ensure_header_written(0)
#   File "/home/kisuke-34/.local/share/uv/python/cpython-3.14-linux-x86_64-gnu/lib/python3.14/wave.py", line 613, in _ensure_header_written
#     raise Error('# channels not specified')
# wave.Error: # channels not specified

# %%
print(hi)
# Out:
# 9

# %%
wav.setframerate(44100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 wav.setframerate(44100)
#
# AttributeError: 'Wave_read' object has no attribute 'setframerate'

# %%
wav = wave.open("output.wav", "wb")

wav.setnchannels(2)
wav.setsampwidth(2)
wav.setframerate(44100)
